# %% [markdown]
# ###  Using API to run the simulation

# %% [markdown]
# We use a strongly defined HTTP API protocol to communicate with a C12 simulator (get and receive the data). This tutorial will briefly present basic API calls that can be used for communication with the C12 simulator. On top of our APIs, different backends can be made to be consistent with other quantum computer frameworks and interfaces.
#
# To run each API, we need to pass the unique bearer token that will be used to verify the user's right to access C12's system.
#
# For communication with C12's system, it is possible to use the API library that encapsulates the HTTP communication with the C12 system using the python request module.
#
# To start using it, we need to create an instance of the Request class, as shown in the following code snippet.

# %%
from c12simulator_clients.api.client import Request

# UserConfig class
from c12simulator_clients.user_configs import UserConfigs
import os
user_auth_token = os.getenv("C12_TOKEN")
# Create the request instance
# Constructor of the Request class also accepts the verbose parameter, which can be use for more detailed output of the methods.

request = Request(auth_token=user_auth_token, verbose=False)

# %% [markdown]
# #### Run the simulation
#
# The method `start_job()` is used to start the simulation. It has the following arguments:
# - `qasm_str`: QASM string with quantum circuit
# - `shots`:  Number of trials for the simulation
# - `result`: what is desired output (statevector, counts, density_matrix)
# - `backend_name`: the name of the backend to run on

# %%
from qiskit import QuantumCircuit

circuit = QuantumCircuit(2)
circuit.h(0)
circuit.cx(0, 1)


qasm_str = circuit.qasm()
job_uuid = request.start_job(
    qasm_str=qasm_str, shots=100, result="density_matrix", backend_name="c12sim"
)

# The function returns the UUID and QASM of started job or HTTP error in case of problems
print(f"job uuid: {job_uuid[0]}")
# Out:
# job uuid: aab2cde9-7a8d-4e27-9e2d-3d46f92382bc

# %% [markdown]
# #### Get the results of a simulation
#
# To get the simulation results, we can use the `get_job_result()` method that accepts one mandatory argument (job UUID string) and two optional ones.
# - `timeout`, which represents the number of seconds that the function will wait for job completion
# - `wait`, number of seconds between each check if the job is finished
#
# If we do not specify a timeout argument the function will run until the result is obtained

# %%
job_result = request.get_job_result(job_uuid[0], timeout=120, wait=5)
print(job_result)
# Out:
# {'status': 'FINISHED', 'results': {'density_matrix': [['(0.49949282437085923-5.493376355137836e-21j)', '(-0.00020111820936445123+0.00015178560957347653j)', '(-8.597498004723175e-05-3.188946233230461e-05j)', '(0.4991873191038138+0.00017373392510153137j)'], ['(-0.00020111820936445123-0.00015178560957342102j)', '(0.00040860052509848754-2.5661881505485718e-21j)', '(3.234086099218603e-05-4.7868039037765916e-05j)', '(0.00010915149728408598-3.189802772829431e-05j)'], ['(-8.597498004723175e-05+3.188946233229073e-05j)', '(3.2340860992130516e-05+4.7868039037765895e-05j)', '(0.0002993751253901472+2.1041523155011936e-21j)', '(-0.00022496660571114015+6.986924686594453e-05j)'], ['(0.4991873191038138-0.00017373392510153137j)', '(0.00010915149728408597+3.189802772829431e-05j)', '(-0.0002249666057111402-6.986924686591678e-05j)', '(0.49979919765436065-4.208983176866398e-21j)']]}, 'errors': ''}

# %% [markdown]
# #### Get the status of the job

# %%
status = request.get_job_status(job_uuid=job_uuid[0])
print(status)
# Out:
# finished

# %% [markdown]
# #### Get all jobs
#
# Method `get_user_jobs()` can be used for obtaining information about all the jobs that have been run on the system for the user whose token is passed to the Request instance.
#
# The method has two arguments:
# - `limit`: an integer that represents the number of results to obtain
# - `offset`: an integer that represents the offset from the first result
#
# Using these two values, one can obtain the pagination, where the offset represents a page and limits the number of results per page. Method returns an array with results.

# %%
number_of_results = 5  # Limit parameter, number of records to retrieve
offset = 0
count = 1
while True:
    jobs = request.get_user_jobs(limit=number_of_results, offset=offset)

    for job in jobs:
        print(f"{count:}")
        print(job)
        count += 1

    if len(jobs) < number_of_results:
        break

    offset += number_of_results
# Out:
# 1
# {'uuid': '5fb57102-ca9e-45dd-875c-cc11a55ca073', 'time': '2023-03-30T13:51:53.976613', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '0', 'result': '2'}
# 2
# {'uuid': '796158fa-d61b-4dee-8d58-8b1d51897ae5', 'time': '2023-03-30T13:52:43.875645', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(-pi/2) q[0];\nrz(-pi) q[0];\nrx(1.815774989921761) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(-pi/2) q[0];\nrz(-2.3713483251754366) q[1];\nry(0.3447011797986471) q[1];\nrz(-2.3713483251754415) q[1];\ncrx(pi) q[0],q[1];\nrz(-pi/2) q[0];\nry(-pi/2) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[1];\nh q[0];\nx q[1];\nx q[0];\ncz q[0],q[1];\nx q[0];\nx q[1];\nh q[0];\nh q[1];\nz q[0];\nz q[1];\ncz q[0],q[1];\nh q[0];\nh q[1];\n', 'errors': 'f', 'result': 'a'}
# 3
# {'uuid': '498c5318-5117-4838-bed9-e177be4fc4e0', 'time': '2023-03-30T13:54:13.943255', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '1', 'result': '8'}
# 4
# {'uuid': 'ac29c1ad-a5f6-496d-b8b6-5eb25e9bffe3', 'time': '2023-03-30T13:54:13.943606', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[3];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\nry(-pi/2) q[2];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[3];\nh q[0];\ncx q[0],q[1];\nx q[2];\nh q[2];\n', 'errors': 'a', 'result': 'd'}
# 5
# {'uuid': '42ea332d-7239-4d77-8ec4-127992208d7e', 'time': '2023-03-30T13:55:11.081487', 'status': 'finished', 'options': {'shots': 100, 'result': 'density_matrix'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '2', 'result': 'd'}
# 6
# {'uuid': '8bbf4762-c376-438f-9fb2-f3d68bcf316b', 'time': '2023-04-12T13:56:18.076014', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '6', 'result': '2'}
# 7
# {'uuid': 'd6c76fd5-b951-419b-8fb7-5baf52251d60', 'time': '2023-04-12T13:57:38.077903', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(-pi/2) q[0];\nrz(-pi) q[0];\nrx(1.815774989921761) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(-pi/2) q[0];\nrz(-2.3713483251754366) q[1];\nry(0.3447011797986471) q[1];\nrz(-2.3713483251754415) q[1];\ncrx(pi) q[0],q[1];\nrz(-pi/2) q[0];\nry(-pi/2) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[1];\nh q[0];\nx q[1];\nx q[0];\ncz q[0],q[1];\nx q[0];\nx q[1];\nh q[0];\nh q[1];\nz q[0];\nz q[1];\ncz q[0],q[1];\nh q[0];\nh q[1];\n', 'errors': 'd', 'result': '5'}
# 8
# {'uuid': 'f1a219cd-a717-4e4c-9c7c-8d53e2125edf', 'time': '2023-04-12T13:59:27.976833', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'c', 'result': 'd'}
# 9
# {'uuid': '75a04f40-6c08-4967-aa63-14113faa7481', 'time': '2023-04-12T14:00:18.864364', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '4', 'result': '0'}
# 10
# {'uuid': 'b6eefcf3-fbd7-4319-8f2b-86aa9cd10036', 'time': '2023-04-12T14:01:23.363990', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'f', 'result': '3'}
# 11
# {'uuid': '997f68b9-bd1f-48ec-8338-2614c6ca45ed', 'time': '2023-04-12T14:01:33.438215', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[3];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\nry(-pi/2) q[2];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[3];\nh q[0];\ncx q[0],q[1];\nx q[2];\nh q[2];\n', 'errors': 'b', 'result': '9'}
# 12
# {'uuid': '2e687eef-4b6d-4ebb-a22f-1c21d088e56d', 'time': '2023-04-12T14:02:38.332928', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(pi) q[0];\nbarrier q[0],q[1];\nrx(pi) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\nbarrier q[0],q[1];\nrx(pi) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\nbarrier q[0],q[1];\ncx q[0],q[1];\nbarrier q[0],q[1];\nx q[1];\n', 'errors': 'e', 'result': 'f'}
# 13
# {'uuid': '30e8debf-c3a7-4d22-86e0-1bf566562150', 'time': '2023-04-12T14:18:55.022457', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'b', 'result': 'f'}
# 14
# {'uuid': '44b8a742-91ba-4dee-a1f0-c04c20a32f46', 'time': '2023-04-12T14:20:39.147978', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(-pi/2) q[0];\nrz(-pi) q[0];\nrx(1.815774989921761) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(-pi/2) q[0];\nrz(-2.3713483251754366) q[1];\nry(0.3447011797986471) q[1];\nrz(-2.3713483251754415) q[1];\ncrx(pi) q[0],q[1];\nrz(-pi/2) q[0];\nry(-pi/2) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[1];\nh q[0];\nx q[1];\nx q[0];\ncz q[0],q[1];\nx q[0];\nx q[1];\nh q[0];\nh q[1];\nz q[0];\nz q[1];\ncz q[0],q[1];\nh q[0];\nh q[1];\n', 'errors': '4', 'result': '2'}
# 15
# {'uuid': '7b0bb738-0d69-43e6-827d-c03f32d904f3', 'time': '2023-04-12T15:21:29.951022', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '3', 'result': '8'}
# 16
# {'uuid': '8605dfd7-3d15-44e5-b98f-f1115779d896', 'time': '2023-04-12T15:43:23.042985', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'd', 'result': '7'}
# 17
# {'uuid': 'a9c90432-df62-4a12-8fd1-bd828b02923f', 'time': '2023-04-12T15:43:33.115355', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '3', 'result': '2'}
# 18
# {'uuid': 'cf8007fa-d972-46bb-80f0-4e4ed898c5af', 'time': '2023-04-12T15:44:20.381368', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(-pi/2) q[0];\nrz(-pi) q[0];\nrx(1.815774989921761) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(-pi/2) q[0];\nrz(-2.3713483251754366) q[1];\nry(0.3447011797986471) q[1];\nrz(-2.3713483251754415) q[1];\ncrx(pi) q[0],q[1];\nrz(-pi/2) q[0];\nry(-pi/2) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[1];\nh q[0];\nx q[1];\nx q[0];\ncz q[0],q[1];\nx q[0];\nx q[1];\nh q[0];\nh q[1];\nz q[0];\nz q[1];\ncz q[0],q[1];\nh q[0];\nh q[1];\n', 'errors': 'f', 'result': 'a'}
# 19
# {'uuid': '0e606d86-8c02-452d-9efa-4c95999f7df7', 'time': '2023-04-12T15:45:43.088446', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '8', 'result': '6'}
# 20
# {'uuid': 'a7020f1a-665c-47dc-869c-bb8a2f75390b', 'time': '2023-04-12T15:47:13.196839', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '1', 'result': 'a'}
# 21
# {'uuid': 'fc0b82cb-7b99-41c2-a6ea-a873645a57bb', 'time': '2023-04-12T15:49:56.971682', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'c', 'result': 'b'}
# 22
# {'uuid': 'e72240a8-d38f-4ec2-b424-e2c252cc562c', 'time': '2023-04-12T15:50:07.016421', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'a', 'result': '8'}
# 23
# {'uuid': 'a88ccfe0-f88c-4558-b34d-115c7786e71b', 'time': '2023-04-12T15:50:37.897649', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(-pi/2) q[0];\nrz(-pi) q[0];\nrx(1.815774989921761) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(-pi/2) q[0];\nrz(-2.3713483251754366) q[1];\nry(0.3447011797986471) q[1];\nrz(-2.3713483251754415) q[1];\ncrx(pi) q[0],q[1];\nrz(-pi/2) q[0];\nry(-pi/2) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[1];\nh q[0];\nx q[1];\nx q[0];\ncz q[0],q[1];\nx q[0];\nx q[1];\nh q[0];\nh q[1];\nz q[0];\nz q[1];\ncz q[0],q[1];\nh q[0];\nh q[1];\n', 'errors': 'e', 'result': '0'}
# 24
# {'uuid': 'a2283e4a-69db-4e54-ae97-7e85c8d69b43', 'time': '2023-04-12T16:05:59.579912', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '4', 'result': 'a'}
# 25
# {'uuid': 'd97bbe2f-d9f3-4da6-a5b8-a137d172483f', 'time': '2023-04-12T16:06:44.170940', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(-pi/2) q[0];\nrz(-pi) q[0];\nrx(1.815774989921761) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(-pi/2) q[0];\nrz(-2.3713483251754366) q[1];\nry(0.3447011797986471) q[1];\nrz(-2.3713483251754415) q[1];\ncrx(pi) q[0],q[1];\nrz(-pi/2) q[0];\nry(-pi/2) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[1];\nh q[0];\nx q[1];\nx q[0];\ncz q[0],q[1];\nx q[0];\nx q[1];\nh q[0];\nh q[1];\nz q[0];\nz q[1];\ncz q[0],q[1];\nh q[0];\nh q[1];\n', 'errors': '2', 'result': 'f'}
# 26
# {'uuid': 'adefd813-1b50-4eb5-a102-b91594e1e8dd', 'time': '2023-04-13T08:17:00.517794', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(pi) q[0];\nbarrier q[0],q[1];\nrx(pi) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\nbarrier q[0],q[1];\nrx(pi) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\nbarrier q[0],q[1];\ncx q[0],q[1];\nbarrier q[0],q[1];\nx q[1];\n', 'errors': '1', 'result': '3'}
# 27
# {'uuid': 'e4e5582c-8a8a-41b2-9357-54d206c21864', 'time': '2023-04-13T09:03:32.811300', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '2', 'result': 'c'}
# 28
# {'uuid': '82d38ab1-0614-499e-a1e7-5c9dec8d0512', 'time': '2023-04-13T09:03:42.083620', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'b', 'result': '1'}
# 29
# {'uuid': 'f16ab6c2-9177-47b4-8539-dd8f6c13bb20', 'time': '2023-04-13T09:04:16.990631', 'status': 'finished', 'options': {'shots': 100, 'result': 'density_matrix'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'c', 'result': '2'}
# 30
# {'uuid': '99a3bd45-1927-4d13-867a-e102d9773ecf', 'time': '2023-04-13T09:44:20.766749', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '4', 'result': '5'}
# 31
# {'uuid': '50b21c93-5e84-4e0a-911d-5ccc06efb9eb', 'time': '2023-04-13T09:44:46.160875', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '9', 'result': '3'}
# 32
# {'uuid': '665e820d-6d5f-4272-92a8-c6fb63b52dc2', 'time': '2023-04-13T09:45:14.755436', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(-pi/2) q[0];\nrz(-pi) q[0];\nrx(1.815774989921761) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(-pi/2) q[0];\nrz(-2.3713483251754366) q[1];\nry(0.3447011797986471) q[1];\nrz(-2.3713483251754415) q[1];\ncrx(pi) q[0],q[1];\nrz(-pi/2) q[0];\nry(-pi/2) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[1];\nh q[0];\nx q[1];\nx q[0];\ncz q[0],q[1];\nx q[0];\nx q[1];\nh q[0];\nh q[1];\nz q[0];\nz q[1];\ncz q[0],q[1];\nh q[0];\nh q[1];\n', 'errors': '0', 'result': 'd'}
# 33
# {'uuid': 'b555fd42-929c-4f56-858c-ce196d21d6c8', 'time': '2023-04-13T09:54:05.202468', 'status': 'finished', 'options': {'shots': 100, 'result': 'density_matrix'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '4', 'result': '2'}
# 34
# {'uuid': '290825a0-175a-455f-a6fa-7f2c5bac6da4', 'time': '2023-04-13T09:55:17.761250', 'status': 'finished', 'options': {'shots': 100, 'result': 'density_matrix'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'a', 'result': '0'}
# 35
# {'uuid': '2473f519-3ceb-4c5e-b36f-4b5e3f996b09', 'time': '2023-04-13T09:57:15.439992', 'status': 'finished', 'options': {'shots': 100, 'result': 'density_matrix'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '1', 'result': '9'}
# 36
# {'uuid': 'd4faced7-86fa-4072-8360-c22931eabc5d', 'time': '2023-04-13T11:30:20.030825', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'd', 'result': '7'}
# 37
# {'uuid': 'b2fe0eb2-129b-4454-b494-416190f93965', 'time': '2023-04-13T11:30:40.219085', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'b', 'result': '2'}
# 38
# {'uuid': 'ece22fa0-2342-4bf9-8691-a4f874727215', 'time': '2023-04-13T11:31:03.807565', 'status': 'finished', 'options': {'shots': 100, 'result': 'density_matrix'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'a', 'result': '0'}
# 39
# {'uuid': '7598fc3b-08c7-4ac2-b412-e8cb57872876', 'time': '2023-04-13T11:31:20.182954', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(pi) q[0];\nbarrier q[0],q[1];\nrx(pi) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\nbarrier q[0],q[1];\nrx(pi) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\nbarrier q[0],q[1];\ncx q[0],q[1];\nbarrier q[0],q[1];\nx q[1];\n', 'errors': '3', 'result': 'b'}
# 40
# {'uuid': 'd287199b-d9ae-4ef9-8aa4-4eda49bcb8c8', 'time': '2023-04-13T11:31:38.957890', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(-pi/2) q[0];\nrz(-pi) q[0];\nrx(1.815774989921761) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(-pi/2) q[0];\nrz(-2.3713483251754366) q[1];\nry(0.3447011797986471) q[1];\nrz(-2.3713483251754415) q[1];\ncrx(pi) q[0],q[1];\nrz(-pi/2) q[0];\nry(-pi/2) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[1];\nh q[0];\nx q[1];\nx q[0];\ncz q[0],q[1];\nx q[0];\nx q[1];\nh q[0];\nh q[1];\nz q[0];\nz q[1];\ncz q[0],q[1];\nh q[0];\nh q[1];\n', 'errors': '9', 'result': 'b'}
# 41
# {'uuid': '584d1b18-c7fd-4c7a-839e-ebc4dd25dfeb', 'time': '2023-04-13T11:31:57.956622', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '1', 'result': '8'}
# 42
# {'uuid': '83c10725-62f9-4a7d-b90f-eca0e67765d1', 'time': '2023-04-13T11:39:20.455354', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '2', 'result': '5'}
# 43
# {'uuid': 'd8d876b5-661b-424b-89b6-6d45b4ead38a', 'time': '2023-04-13T11:39:30.515386', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'b', 'result': '5'}
# 44
# {'uuid': 'eff90f9f-d8bf-42a6-9d7d-7c541e125fe1', 'time': '2023-04-13T11:39:58.267396', 'status': 'finished', 'options': {'shots': 100, 'result': 'density_matrix'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '9', 'result': 'f'}
# 45
# {'uuid': '02115036-a210-42a4-9e37-b2dcb1468f6d', 'time': '2023-04-13T11:40:07.796049', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(-pi/2) q[0];\nrz(-pi) q[0];\nrx(1.815774989921761) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(-pi/2) q[0];\nrz(-2.3713483251754366) q[1];\nry(0.3447011797986471) q[1];\nrz(-2.3713483251754415) q[1];\ncrx(pi) q[0],q[1];\nrz(-pi/2) q[0];\nry(-pi/2) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[1];\nh q[0];\nx q[1];\nx q[0];\ncz q[0],q[1];\nx q[0];\nx q[1];\nh q[0];\nh q[1];\nz q[0];\nz q[1];\ncz q[0],q[1];\nh q[0];\nh q[1];\n', 'errors': '3', 'result': '6'}
# 46
# {'uuid': 'e3ce8346-869d-4813-9fdd-b38e03d99183', 'time': '2023-04-13T11:40:46.546709', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '4', 'result': '6'}
# 47
# {'uuid': '3579f7f1-0762-429d-849f-4fadfcac84c2', 'time': '2023-04-18T09:14:55.048110', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'f', 'result': '1'}
# 48
# {'uuid': '79c793aa-a30c-448d-8138-f95d53753ae5', 'time': '2023-04-18T09:22:25.385347', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'a', 'result': 'a'}
# 49
# {'uuid': '1f570cbf-6b42-4a06-be7f-a86a2b5524b9', 'time': '2023-04-18T09:24:25.525410', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(pi) q[0];\nbarrier q[0],q[1];\nrx(pi) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\nbarrier q[0],q[1];\nrx(pi) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\nbarrier q[0],q[1];\ncx q[0],q[1];\nbarrier q[0],q[1];\nx q[1];\n', 'errors': 'b', 'result': 'f'}
# 50
# {'uuid': '3059ef39-97dd-4478-88d0-03783bbda5a1', 'time': '2023-04-18T09:30:25.737796', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(pi) q[0];\nbarrier q[0],q[1];\nrx(pi) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\nbarrier q[0],q[1];\nrx(pi) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\nbarrier q[0],q[1];\ncx q[0],q[1];\nbarrier q[0],q[1];\nx q[1];\n', 'errors': '3', 'result': '9'}
# 51
# {'uuid': '2bdb750c-9582-4c14-8e9d-cbb0ef41038b', 'time': '2023-04-18T09:35:30.596109', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(pi) q[0];\nbarrier q[0],q[1];\nrx(pi) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\nbarrier q[0],q[1];\nrx(pi) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\nbarrier q[0],q[1];\ncx q[0],q[1];\nbarrier q[0],q[1];\nx q[1];\n', 'errors': '0', 'result': 'c'}
# 52
# {'uuid': '51bee741-92c2-4ead-ba49-263be666435b', 'time': '2023-04-18T09:49:35.062635', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(pi) q[0];\nbarrier q[0],q[1];\nrx(pi) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\nbarrier q[0],q[1];\nrx(pi) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\nbarrier q[0],q[1];\ncx q[0],q[1];\nbarrier q[0],q[1];\nx q[1];\n', 'errors': '4', 'result': '1'}
# 53
# {'uuid': '4fe8d234-75f1-44bb-aea5-364d6cd3dc7a', 'time': '2023-04-19T15:30:26.264672', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '3', 'result': '4'}
# 54
# {'uuid': '31da0b4c-33a6-46d7-b1a5-7b523cd4b0d0', 'time': '2023-04-19T15:38:23.094982', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '4', 'result': 'c'}
# 55
# {'uuid': '53f427d0-e6cd-4454-ab15-8eed6b66907c', 'time': '2023-04-19T20:40:37.446037', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'd', 'result': '0'}
# 56
# {'uuid': 'ddcd4469-3903-4b90-b5d8-6759365fb483', 'time': '2023-04-20T07:45:20.211861', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '6', 'result': '9'}
# 57
# {'uuid': '511138d6-91d9-41a6-8c00-7c25ebca72dd', 'time': '2023-04-20T07:47:00.024676', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'd', 'result': '6'}
# 58
# {'uuid': 'd0db6896-335c-40b5-8c1b-66cfe40f10b8', 'time': '2023-04-21T12:00:36.886534', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '9', 'result': '6'}
# 59
# {'uuid': '4fca0500-793c-40c5-9d51-c789a1ee2820', 'time': '2023-04-21T12:02:03.217571', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(-pi/2) q[0];\nrz(-pi) q[0];\nrx(1.815774989921761) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(-pi/2) q[0];\nrz(-2.3713483251754366) q[1];\nry(0.3447011797986471) q[1];\nrz(-2.3713483251754415) q[1];\ncrx(pi) q[0],q[1];\nrz(-pi/2) q[0];\nry(-pi/2) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[1];\nh q[0];\nx q[1];\nx q[0];\ncz q[0],q[1];\nx q[0];\nx q[1];\nh q[0];\nh q[1];\nz q[0];\nz q[1];\ncz q[0],q[1];\nh q[0];\nh q[1];\n', 'errors': '0', 'result': '0'}
# 60
# {'uuid': '13b9ab2e-79ce-42ba-be59-5c115a5c10ef', 'time': '2023-04-21T12:06:23.005700', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '2', 'result': 'e'}
# 61
# {'uuid': 'e2bb0462-7b6f-4f51-8f6b-be8a1653b23d', 'time': '2023-04-21T12:13:04.633251', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '6', 'result': '2'}
# 62
# {'uuid': 'ed505ff9-fdcc-4c36-8e21-f6fa909d0733', 'time': '2023-04-21T12:13:53.238874', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'f', 'result': '9'}
# 63
# {'uuid': '3d09270e-1109-495a-8222-ba5049c0ad59', 'time': '2023-04-21T12:15:03.364547', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '0', 'result': 'e'}
# 64
# {'uuid': '9f360c45-d6c9-4d5c-8573-8c42a575eadb', 'time': '2023-04-21T12:15:03.366850', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[3];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\nry(-pi/2) q[2];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[3];\nh q[0];\ncx q[0],q[1];\nx q[2];\nh q[2];\n', 'errors': '4', 'result': '5'}
# 65
# {'uuid': '82de15ae-4932-4a90-b5ed-c78a384535fd', 'time': '2023-04-21T12:22:43.810995', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(pi) q[0];\nbarrier q[0],q[1];\nrx(pi) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\nbarrier q[0],q[1];\nrx(pi) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\nbarrier q[0],q[1];\ncx q[0],q[1];\nbarrier q[0],q[1];\nx q[1];\n', 'errors': 'a', 'result': 'e'}
# 66
# {'uuid': '1ac4d9dd-c595-4510-a071-ad1ea5e7004a', 'time': '2023-04-21T15:39:43.215427', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'd', 'result': 'd'}
# 67
# {'uuid': '96684538-e25b-4b02-abb1-45bb0eeba2e0', 'time': '2023-04-24T12:13:04.262470', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '3', 'result': '8'}
# 68
# {'uuid': '26a92e1d-e540-43fa-b3f1-79dad9ce19c0', 'time': '2023-04-24T15:02:14.737875', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '1', 'result': 'd'}
# 69
# {'uuid': '28e2b00b-2df7-44c6-a206-1682dcc2f4f9', 'time': '2023-04-24T15:11:08.435085', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '0', 'result': 'b'}
# 70
# {'uuid': '38a0c548-5b6e-4e42-ac38-249faf7e53bf', 'time': '2023-04-24T15:20:28.756479', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '4', 'result': '8'}
# 71
# {'uuid': '403e8a7a-6f44-4912-ba49-3f0635a9961c', 'time': '2023-04-24T15:22:08.961668', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '7', 'result': 'a'}
# 72
# {'uuid': 'ab3d8b52-0764-43d4-849d-0e976eae1074', 'time': '2023-04-24T15:23:08.973449', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '5', 'result': '2'}
# 73
# {'uuid': 'f6955702-bf42-4cf4-8086-b3780e6c345a', 'time': '2023-04-24T15:48:10.355729', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nx q[0];\ncx q[0],q[1];\n', 'errors': '0', 'result': '2'}
# 74
# {'uuid': '9ebff2db-3758-4072-808b-b01699a9236b', 'time': '2023-04-24T15:51:40.366937', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nx q[0];\ncx q[0],q[1];\n', 'errors': 'd', 'result': 'b'}
# 75
# {'uuid': 'f9ecae35-75f1-47bb-9b5b-01ec4bd6700b', 'time': '2023-04-25T14:11:04.877653', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '3', 'result': '5'}
# 76
# {'uuid': '27daaeb4-1f91-48b2-b477-37c9ef3e99f1', 'time': '2023-05-02T12:15:52.632865', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'b', 'result': '4'}
# 77
# {'uuid': '1c15b84d-0699-4ac3-a6fe-fbf81441c2e0', 'time': '2023-05-02T12:17:22.174182', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(-pi/2) q[0];\nrz(-pi) q[0];\nrx(1.815774989921761) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(-pi/2) q[0];\nrz(-2.3713483251754366) q[1];\nry(0.3447011797986471) q[1];\nrz(-2.3713483251754415) q[1];\ncrx(pi) q[0],q[1];\nrz(-pi/2) q[0];\nry(-pi/2) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[1];\nh q[0];\nx q[1];\nx q[0];\ncz q[0],q[1];\nx q[0];\nx q[1];\nh q[0];\nh q[1];\nz q[0];\nz q[1];\ncz q[0],q[1];\nh q[0];\nh q[1];\n', 'errors': '4', 'result': 'd'}
# 78
# {'uuid': '0da44c8d-cad0-46e5-82fe-b8f3ffe47f44', 'time': '2023-05-02T12:26:22.971065', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(-pi/2) q[0];\nrz(-pi) q[0];\nrx(1.815774989921761) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(-pi/2) q[0];\nrz(-2.3713483251754366) q[1];\nry(0.3447011797986471) q[1];\nrz(-2.3713483251754415) q[1];\ncrx(pi) q[0],q[1];\nrz(-pi/2) q[0];\nry(-pi/2) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[1];\nh q[0];\nx q[1];\nx q[0];\ncz q[0],q[1];\nx q[0];\nx q[1];\nh q[0];\nh q[1];\nz q[0];\nz q[1];\ncz q[0],q[1];\nh q[0];\nh q[1];\n', 'errors': '8', 'result': 'd'}
# 79
# {'uuid': 'c6bf7e11-e3da-4107-8987-d2e8e6137d3e', 'time': '2023-05-02T12:27:32.472558', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(-pi/2) q[0];\nrz(-pi) q[0];\nrx(1.815774989921761) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(-pi/2) q[0];\nrz(-2.3713483251754366) q[1];\nry(0.3447011797986471) q[1];\nrz(-2.3713483251754415) q[1];\ncrx(pi) q[0],q[1];\nrz(-pi/2) q[0];\nry(-pi/2) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[1];\nh q[0];\nx q[1];\nx q[0];\ncz q[0],q[1];\nx q[0];\nx q[1];\nh q[0];\nh q[1];\nz q[0];\nz q[1];\ncz q[0],q[1];\nh q[0];\nh q[1];\n', 'errors': '1', 'result': '1'}
# 80
# {'uuid': '38fcda38-8db1-469a-b357-a9a3e62d313f', 'time': '2023-05-04T09:43:09.174702', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '3', 'result': '8'}
# 81
# {'uuid': '8310ea70-1164-458f-b503-65bec1925510', 'time': '2023-05-05T08:44:36.231777', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '7', 'result': '0'}
# 82
# {'uuid': '8caf41bc-fd4e-43a1-8db7-8ab30c01d0ba', 'time': '2023-05-12T07:36:02.674922', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[1];\nrx(pi) q[0];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[1];\nx q[0];\n', 'errors': 'b', 'result': 'c'}
# 83
# {'uuid': 'd8ee2653-335b-4ed1-b560-5277fb24e3bd', 'time': '2023-05-12T07:37:32.744090', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[1];\nrz(pi) q[0];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[1];\nz q[0];\n', 'errors': '5', 'result': '3'}
# 84
# {'uuid': '4bd9007f-7cca-4ca2-a16b-03e0641b9547', 'time': '2023-05-12T07:40:02.858272', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[1];\nrx(pi/2) q[0];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[1];\nrx(pi/2) q[0];\n', 'errors': '7', 'result': 'f'}
# 85
# {'uuid': '83dc97bc-a931-45c1-b975-119193f96eea', 'time': '2023-05-12T07:41:12.999389', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[1];\nrz(pi) q[0];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[1];\nrz(pi) q[0];\n', 'errors': 'b', 'result': 'c'}
# 86
# {'uuid': 'b3d45c20-b80b-44f5-90f3-21018f833f22', 'time': '2023-05-12T07:42:32.994250', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\ncrx(pi/2) q[0],q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\ncrx(pi/2) q[0],q[1];\n', 'errors': '2', 'result': '0'}
# 87
# ...
# 321
# {'uuid': '33dce03b-9825-4b3f-a7f9-f775b16ccd0a', 'time': '2023-05-17T14:22:48.481466', 'status': 'finished', 'options': {'shots': 10, 'result': 'counts,statevector', 'paramsjson': "{'power_spect_const': 5e-06}", 'basis': 'iswap'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\nrx(pi) q[0];\niswap q[0],q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\nx q[0];\niswap q[0],q[1];\n', 'errors': '3', 'result': 'b'}
# 322
# {'uuid': '17937284-016b-4f07-bdf1-10987a6d4377', 'time': '2023-05-17T14:23:24.733602', 'status': 'finished', 'options': {'shots': 10, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nrz(pi) q[0];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nz q[0];\n', 'errors': '8', 'result': '4'}
# 323
# {'uuid': 'ec883493-02e1-4de5-9667-8c8b84a3a146', 'time': '2023-05-17T14:23:50.445194', 'status': 'finished', 'options': {'shots': 100, 'result': 'counts,statevector', 'paramsjson': "{'power_spect_const': 5e-06}", 'basis': 'iswap'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\nrx(pi) q[0];\niswap q[0],q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\nx q[0];\niswap q[0],q[1];\n', 'errors': '9', 'result': '3'}
# 324
# {'uuid': '82f91f51-bac1-4134-bf8b-d3930ddab2aa', 'time': '2023-05-17T14:24:49.679532', 'status': 'finished', 'options': {'shots': 10, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nrx(pi) q[0];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nx q[0];\n', 'errors': '5', 'result': '1'}
# 325
# {'uuid': '841a90ea-84aa-4200-bacf-8730b9c281ef', 'time': '2023-05-17T14:25:02.885252', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector', 'paramsjson': "{'power_spect_const': 5e-06}", 'basis': 'iswap'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\nrx(pi) q[0];\niswap q[0],q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\nx q[0];\niswap q[0],q[1];\n', 'errors': 'e', 'result': 'a'}
# 326
# {'uuid': '91d00780-fed2-4004-98e1-ee354793dc5d', 'time': '2023-05-22T15:57:39.331245', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '8', 'result': '0'}
# 327
# {'uuid': '207e70e8-7bf1-4fa9-96fb-01494c06ea08', 'time': '2023-05-22T16:22:35.355944', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector', 'basis': 'iswap'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\niswap q[0],q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\niswap q[0],q[1];\n', 'errors': 'e', 'result': '8'}
# 328
# {'uuid': 'e32d08f7-f418-45b5-a572-90e792e033ba', 'time': '2023-05-23T10:29:21.428255', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector', 'basis': 'iswap'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\nry(-pi/2) q[1];\niswap q[0],q[1];\nrx(pi) q[0];\nry(-pi/2) q[1];\niswap q[0],q[1];\nry(-pi/2) q[0];\nrz(-pi/2) q[0];\nrz(pi/2) q[1];\nry(-pi/2) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'f', 'result': '7'}
# 329
# {'uuid': 'a96d7d4e-62c9-4560-8c31-a40a15748b51', 'time': '2023-05-23T10:31:01.655898', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector', 'basis': 'iswap'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\nry(-pi/2) q[1];\niswap q[0],q[1];\nrx(pi) q[0];\nry(-pi/2) q[1];\niswap q[0],q[1];\nry(-pi/2) q[0];\nrz(-pi/2) q[0];\nrz(pi/2) q[1];\nry(-pi/2) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '4', 'result': 'e'}
# 330
# {'uuid': 'f86b22f5-f772-4da9-8476-4a47583083ce', 'time': '2023-05-23T10:32:21.553482', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector', 'basis': 'iswap'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\nry(-pi/2) q[1];\niswap q[0],q[1];\nrx(pi) q[0];\nry(-pi/2) q[1];\niswap q[0],q[1];\nry(-pi/2) q[0];\nrz(-pi/2) q[0];\nrz(pi/2) q[1];\nry(-pi/2) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'f', 'result': '5'}
# 331
# {'uuid': '2fa3ac07-133f-4d48-a771-1b84cb076ece', 'time': '2023-05-23T10:42:31.150834', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector', 'basis': 'iswap'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\nry(-pi/2) q[1];\niswap q[0],q[1];\nrx(pi) q[0];\nry(-pi/2) q[1];\niswap q[0],q[1];\nry(-pi/2) q[0];\nrz(-pi/2) q[0];\nrz(pi/2) q[1];\nry(-pi/2) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '0', 'result': '7'}
# 332
# {'uuid': 'f8bebcdc-05fc-49d7-8087-f069a4cf4ab0', 'time': '2023-05-23T10:45:00.934813', 'status': 'error', 'options': {'shots': 1024, 'result': 'counts,statevector', 'paramsjson': "{'Omega_d': 6000000000.0}", 'basis': 'iswap'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\nry(-pi/2) q[1];\niswap q[0],q[1];\nrx(pi) q[0];\nry(-pi/2) q[1];\niswap q[0],q[1];\nry(-pi/2) q[0];\nrz(-pi/2) q[0];\nrz(pi/2) q[1];\nry(-pi/2) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'd', 'result': 'c'}
# 333
# {'uuid': 'ca371821-04dd-469e-85bd-eb52476c03af', 'time': '2023-05-23T10:47:01.020592', 'status': 'error', 'options': {'shots': 1024, 'result': 'counts,statevector', 'paramsjson': "{'Omega_d': 6000000000.0}", 'basis': 'iswap'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\nry(-pi/2) q[1];\niswap q[0],q[1];\nrx(pi) q[0];\nry(-pi/2) q[1];\niswap q[0],q[1];\nry(-pi/2) q[0];\nrz(-pi/2) q[0];\nrz(pi/2) q[1];\nry(-pi/2) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '2', 'result': '1'}
# 334
# {'uuid': '832c4b7b-44a7-4294-aaa0-84df7e331275', 'time': '2023-05-23T10:50:11.885248', 'status': 'error', 'options': {'shots': 1024, 'result': 'counts,statevector', 'paramsjson': "{'Omega_d': 6000000000.0}", 'basis': 'iswap'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\nry(-pi/2) q[1];\niswap q[0],q[1];\nrx(pi) q[0];\nry(-pi/2) q[1];\niswap q[0],q[1];\nry(-pi/2) q[0];\nrz(-pi/2) q[0];\nrz(pi/2) q[1];\nry(-pi/2) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '7', 'result': 'b'}
# 335
# {'uuid': 'ef2b18d3-54fe-437e-a4a8-011d5ff39e24', 'time': '2023-05-24T15:05:48.454297', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'd', 'result': '3'}
# 336
# {'uuid': 'f08fdf65-798d-4ba6-938b-dcee9c25a569', 'time': '2023-05-24T15:54:50.631706', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector', 'basis': 'iswap'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\nry(-pi/2) q[1];\niswap q[0],q[1];\nrx(pi) q[0];\nry(-pi/2) q[1];\niswap q[0],q[1];\nry(-pi/2) q[0];\nrz(-pi/2) q[0];\nrz(pi/2) q[1];\nry(-pi/2) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '6', 'result': '5'}
# 337
# {'uuid': 'ad5a1d4e-a455-4cea-af68-88dc4c99178d', 'time': '2023-05-24T15:56:31.720571', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector', 'basis': 'iswap'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\nry(-pi/2) q[1];\niswap q[0],q[1];\nrx(pi) q[0];\nry(-pi/2) q[1];\niswap q[0],q[1];\nry(-pi/2) q[0];\nrz(-pi/2) q[0];\nrz(pi/2) q[1];\nry(-pi/2) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '4', 'result': 'e'}
# 338
# {'uuid': 'cea02904-80fd-4be3-95fd-e17f56508753', 'time': '2023-05-24T15:57:30.895224', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '0', 'result': '4'}
# 339
# {'uuid': 'bc7e0986-33dd-416e-af81-776ed9556f4e', 'time': '2023-05-24T16:01:03.462184', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector', 'basis': 'iswap'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\nrz(-pi) q[0];\nrz(-pi) q[1];\nry(-pi/2) q[1];\niswap q[0],q[1];\nrx(pi) q[0];\nry(-pi/2) q[1];\niswap q[0],q[1];\nry(-pi/2) q[0];\nrz(-pi/2) q[0];\nrz(-pi/2) q[1];\nry(pi/2) q[1];\niswap q[0],q[1];\nrx(pi) q[0];\nry(-pi/2) q[1];\niswap q[0],q[1];\nrx(pi/2) q[0];\nrz(pi/2) q[1];\nry(-pi/2) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[1];\nh q[0];\nx q[1];\nx q[0];\ncz q[0],q[1];\nx q[0];\nx q[1];\nh q[0];\nh q[1];\nz q[0];\nz q[1];\ncz q[0],q[1];\nh q[0];\nh q[1];\n', 'errors': '8', 'result': '6'}
# 340
# {'uuid': '9cccea2f-827c-4297-9b70-d7dcc2560e9a', 'time': '2023-05-24T16:02:51.033931', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector', 'basis': 'iswap'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\ngate iswap q0,q1 { s q0; s q1; h q0; cx q0,q1; cx q1,q0; h q1; }\nqreg q[2];\nrz(-pi) q[0];\nrz(-pi) q[1];\nry(-pi/2) q[1];\niswap q[0],q[1];\nrx(pi) q[0];\nry(-pi/2) q[1];\niswap q[0],q[1];\nry(-pi/2) q[0];\nrz(-pi/2) q[0];\nrz(-pi/2) q[1];\nry(pi/2) q[1];\niswap q[0],q[1];\nrx(pi) q[0];\nry(-pi/2) q[1];\niswap q[0],q[1];\nrx(pi/2) q[0];\nrz(pi/2) q[1];\nry(-pi/2) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[1];\nh q[0];\nx q[1];\nx q[0];\ncz q[0],q[1];\nx q[0];\nx q[1];\nh q[0];\nh q[1];\nz q[0];\nz q[1];\ncz q[0],q[1];\nh q[0];\nh q[1];\n', 'errors': '2', 'result': 'f'}
# 341
# {'uuid': '089143ce-78bd-4d9c-824c-debd413e8e53', 'time': '2023-05-24T16:05:31.239780', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'c', 'result': 'e'}
# 342
# {'uuid': '45c4fbc7-61c8-45f0-8dfa-ff4b5ef36ad4', 'time': '2023-05-24T16:06:21.197130', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'c', 'result': '7'}
# 343
# {'uuid': 'ea95980b-51b1-4011-912b-60a73c4eadd1', 'time': '2023-05-24T16:07:31.343549', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '0', 'result': 'b'}
# 344
# {'uuid': '61a6844b-e473-40fe-ab9e-2b793caec1a0', 'time': '2023-05-24T16:11:21.409426', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '4', 'result': 'b'}
# 345
# {'uuid': '6d9a97dd-bee9-4987-9c35-cf001c36fc32', 'time': '2023-05-24T16:11:21.410154', 'status': 'finished', 'options': {'shots': 1024, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[3];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\nry(-pi/2) q[2];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[3];\nh q[0];\ncx q[0],q[1];\nx q[2];\nh q[2];\n', 'errors': 'd', 'result': 'd'}
# 346
# {'uuid': '44750f6a-9a5e-41db-b605-aa15b9e9f465', 'time': '2023-05-24T16:14:51.604338', 'status': 'finished', 'options': {'shots': 10000, 'result': 'counts,statevector'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(pi) q[0];\nbarrier q[0],q[1];\nrx(pi) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\nbarrier q[0],q[1];\nrx(pi) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\nbarrier q[0],q[1];\ncx q[0],q[1];\nbarrier q[0],q[1];\nx q[1];\n', 'errors': '6', 'result': 'a'}
# 347
# {'uuid': '17642809-7c19-4b2a-b56b-5815a6ac25e8', 'time': '2023-05-25T08:11:18.448369', 'status': 'finished', 'options': {'shots': 100, 'result': 'density_matrix'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '0', 'result': '9'}
# 348
# {'uuid': 'aab2cde9-7a8d-4e27-9e2d-3d46f92382bc', 'time': '2023-05-25T08:14:08.244385', 'status': 'finished', 'options': {'shots': 100, 'result': 'density_matrix'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': 'e', 'result': '9'}

# %% [markdown]
# #### Get information about a specific job
#
# Using the method `get_job()` it is possible to retrieve the information about the specific job with a given UUID.

# %%
job_data = request.get_job(job_uuid[0])
print(job_data)
# Out:
# {'uuid': 'aab2cde9-7a8d-4e27-9e2d-3d46f92382bc', 'time': '2023-05-25T08:14:08.244385', 'status': 'finished', 'options': {'shots': 100, 'result': 'density_matrix'}, 'task': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nry(pi/2) q[0];\nrx(-1.8157749899217606) q[1];\nrz(-pi) q[1];\ncrx(pi) q[0],q[1];\nrz(pi/2) q[0];\nry(pi) q[0];\nrz(-pi) q[1];\nrx(-1.3258176636680312) q[1];\n', 'task_orig': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\nh q[0];\ncx q[0],q[1];\n', 'errors': '', 'result': {'statevector': ['(0.49949282437085923-5.493376355137836e-21j)', '(0.00040860052509848754-2.5661881505485718e-21j)', '(0.0002993751253901472+2.1041523155011936e-21j)', '(0.49979919765436065-4.208983176866398e-21j)'], 'density_matrix': [['(0.49949282437085923-5.493376355137836e-21j)', '(-0.00020111820936445123+0.00015178560957347653j)', '(-8.597498004723175e-05-3.188946233230461e-05j)', '(0.4991873191038138+0.00017373392510153137j)'], ['(-0.00020111820936445123-0.00015178560957342102j)', '(0.00040860052509848754-2.5661881505485718e-21j)', '(3.234086099218603e-05-4.7868039037765916e-05j)', '(0.00010915149728408598-3.189802772829431e-05j)'], ['(-8.597498004723175e-05+3.188946233229073e-05j)', '(3.2340860992130516e-05+4.7868039037765895e-05j)', '(0.0002993751253901472+2.1041523155011936e-21j)', '(-0.00022496660571114015+6.986924686594453e-05j)'], ['(0.4991873191038138-0.00017373392510153137j)', '(0.00010915149728408597+3.189802772829431e-05j)', '(-0.0002249666057111402-6.986924686591678e-05j)', '(0.49979919765436065-4.208983176866398e-21j)']], 'counts': {'00 ': 48, '11 ': 52}, 'states': {'density_matrix': {}, 'statevector': {}}}}
